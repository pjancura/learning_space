# %%
# imports
import plotly
from plotly import __version__
print(__version__)
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly.graph_objs as go
import chart_studio.plotly as cs
import chart_studio.tools as cstools
import plotly.figure_factory as ff
import pandas as pd
import geopandas as gp
import shapely
import shapefile



# Jupyter setup
init_notebook_mode(connected=True)
# Out:
# 5.17.0
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.26.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
 # df means dataframe
df = pd.read_csv('P48-Creating-Maps-Minority-Majority.csv')
scope = ['New York']

# %%
df.head(10)
# Out:
#     FIPS   STNAME           CTYNAME  TOT_POP  TOT_MALE  TOT_FEMALE  WA_MALE  \
# 0  18049  Indiana     Fulton County    20737     10369       10368     9985
# 1  18051  Indiana     Gibson County    33458     16642       16816    15873
# 2  18053  Indiana      Grant County    69330     33282       36048    29587
# 3  18055  Indiana     Greene County    32940     16479       16461    16179
# 4  18057  Indiana   Hamilton County   289495    141103      148392   125675
# 5  18059  Indiana    Hancock County    70933     34932       36001    33383
# 6  18061  Indiana   Harrison County    39134     19579       19555    19107
# 7  18063  Indiana  Hendricks County   150434     75116       75318    67458
# 8  18065  Indiana      Henry County    49345     25337       24008    23856
# 9  18067  Indiana     Howard County    82849     39921       42928    35465
#
#    WA_FEMALE  NHWA_MALE  NHWA_FEMALE  NHWhite_Alone  Not_NHWhite_Alone  \
# 0      10020       9561         9627          19188               1549
# 1      16117      15648        15955          31603               1855
# 2      32460      28353        31398          59751               9579
# 3      16167      16029        15999          32028                912
# 4     131785     120979       127105         248084              41411
# 5      34328      32829        33752          66581               4352
# 6      19119      18795        18868          37663               1471
# 7      68468      65249        66455         131704              18730
# 8      23361      23439        23091          46530               2815
# 9      38322      34468        37359          71827              11022
#
#   MinorityMinority MinorityPCT  Black BlackPCT  Hispanic HispanicPCT
# 0               No       7.47%    170       1%       965       4.65%
# 1               No       5.54%    667       2%       476       1.42%
# 2               No      13.82%   4936       7%      2656       3.83%
# 3               No       2.77%     82       0%       351       1.07%
# 4               No      14.30%  11332       4%     10548       3.64%
# 5               No       6.14%   1491       2%      1266       1.78%
# 6               No       3.76%    231       1%       646       1.65%
# 7               No      12.45%   8311       6%      4855       3.23%
# 8               No       5.70%   1253       3%       756       1.53%
# 9               No      13.30%   5879       7%      2373       2.86%

# %%
# new dataframe name
df_new = df[df['STNAME'].isin(scope)]

# list values
values = df_new['TOT_POP'].tolist()
fips = df_new['FIPS'].tolist()

#have to have the colorscale values at least = to the # of counties
colorscale = ["#2daa4b", "#80b1d3", "#fdb462", "#b3de69", "#fccde5", "#ff0000", "#cce6f4",
              "#80b1d3", "#fdb462", "#b3de69", "#fccde5", "#9ba991", "#604d74", "#afcbc7",
              "#80b1d3", "#fdb462", "#b3de69", "#fccde5", "#f0c800", "#387e75", "#fce7e7",
              "#8dd3c7", "#ffffb3", "#bebada", "#fb8072", "#00778b", "#1d2d43", "#460606",
              "#8dd3c7", "#ffffb3", "#bebada", "#fb8072", "#af3205", "#436e6f", "#f6a2a2",
              "#d9d9d9", "#bc80bd", "#ccebc5", "#ffed6f", "#5a3791", "#1d2d43", "#0068a0",
              "#d9d9d9", "#bc80bd", "#ccebc5", "#ffed6f", "#f6c4d2", "#675974", "#bb1212",
              "#d9d9d9", "#bc80bd", "#ccebc5", "#ffed6f", "#ffd03e", "#4f5573", "#327169",
              "#3697dd", "#8dd3c7", "#ffffb3", "#bebada", "#fb8072", "#ea1717", "#66b4de",]

# %%
fig = ff.create_choropleth(
        fips=fips, values=values, scope=scope,
        colorscale=colorscale, round_legend_values=True,
        simplify_county=0, simplify_state=0,
        county_outline={'color': 'rgb(15,15,55)', 'width': 0.5},
        state_outline={'width': 0.5},
        legend_title='Population Per County',
        title='New York')
# Out:
# /usr/local/anaconda3/envs/plotly_env/lib/python3.10/site-packages/plotly/figure_factory/_county_choropleth.py:775: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# /usr/local/anaconda3/envs/plotly_env/lib/python3.10/site-packages/plotly/figure_factory/_county_choropleth.py:331: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# /usr/local/anaconda3/envs/plotly_env/lib/python3.10/site-packages/plotly/figure_factory/_county_choropleth.py:775: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# /usr/local/anaconda3/envs/plotly_env/lib/python3.10/site-packages/plotly/figure_factory/_county_choropleth.py:331: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# /usr/local/anaconda3/envs/plotly_env/lib/python3.10/site-packages/plotly/figure_factory/_county_choropleth.py:775: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# /usr/local/anaconda3/envs/plotly_env/lib/python3.10/site-packages/plotly/figure_factory/_county_choropleth.py:331: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# /usr/local/anaconda3/envs/plotly_env/lib/python3.10/site-packages/plotly/figure_factory/_county_choropleth.py:358: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 fig = ff.create_choropleth(
#       2         fips=fips, values=values, scope=scope,
#       3         colorscale=colorscale, round_legend_values=True,
#       4         simplify_county=0, simplify_state=0,
#       5         county_outline={'color': 'rgb(15,15,55)', 'width': 0.5},
#       6         state_outline={'width': 0.5},
#       7         legend_title='Population Per County',
#       8         title='New York')
#
# File /usr/local/anaconda3/envs/plotly_env/lib/python3.10/site-packages/plotly/figure_factory/_county_choropleth.py:783, in create_choropleth(fips, values, scope, binning_endpoints, colorscale, order, simplify_county, simplify_state, asp, show_hover, show_state_data, state_outline, county_outline, centroid_marker, round_legend_values, exponent_format, legend_title, **layout_options)
#     774 try:
#     775     fips_polygon_map[f].type
#     777     (
#     778         x_traces,
#     779         y_traces,
#     780         x_centroids,
#     781         y_centroids,
#     782         centroid_text,
# --> 783     ) = _calculations(
#     784         df,
#     785         fips,
#     786         values,
#     787         index,
#     788         f,
#     789         simplify_county,
#     790         level,
#     791         x_centroids,
#     792         y_centroids,
#     793         centroid_text,
#     794         x_traces,
#     795         y_traces,
#     796         fips_polygon_map,
#     797     )
#     798 except KeyError:
#     799     fips_not_in_shapefile.append(f)
#
# File /usr/local/anaconda3/envs/plotly_env/lib/python3.10/site-packages/plotly/figure_factory/_county_choropleth.py:359, in _calculations(df, fips, values, index, f, simplify_county, level, x_centroids, y_centroids, centroid_text, x_traces, y_traces, fips_polygon_map)
#     357     y_traces[level] = y_traces[level] + y + [np.nan]
#     358 elif fips_polygon_map[f].type == "MultiPolygon":
# --> 359     x = [
#     360         poly.simplify(simplify_county).exterior.xy[0].tolist()
#     361         for poly in fips_polygon_map[f]
#     362     ]
#     363     y = [
#     364         poly.simplify(simplify_county).exterior.xy[1].tolist()
#     365         for poly in fips_polygon_map[f]
#     366     ]
#     368     x_c = [poly.centroid.xy[0].tolist() for poly in fips_polygon_map[f]]
#
# TypeError: 'MultiPolygon' object is not iterable
